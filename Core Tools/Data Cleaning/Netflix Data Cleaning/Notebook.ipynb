# %%
# %pip install pandas

import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dataset...

data = pd.read_csv("data/datasets/ariyoomotade/netflix-data-cleaning-analysis-and-visualization/versions/1/netflix1.csv")

data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
cleaned_data = data.copy()

cleaned_data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# ### Deleting redundant columns...

# %%
cleaned_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
cleaned_data[["rating"]]
# Out:
#      rating
# 0     PG-13
# 1     TV-MA
# 2     TV-MA
# 3     TV-PG
# 4     TV-MA
# ...     ...
# 8785  TV-PG
# 8786  TV-Y7
# 8787  TV-PG
# 8788   TV-Y
# 8789  TV-Y7
#
# [8790 rows x 1 columns]

# %%
cleaned_data.drop(columns=["rating"], inplace=True)

# %%
cleaned_data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'duration', 'listed_in'],
#       dtype='object')

# %% [markdown]
# ### Renaming columns...

# %%
new_column_names = []

for i in cleaned_data.columns:
    new_column_names.append(i.capitalize())

cleaned_data.columns = new_column_names

cleaned_data.columns
# Out:
# Index(['Show_id', 'Type', 'Title', 'Director', 'Country', 'Date_added',
#        'Release_year', 'Duration', 'Listed_in'],
#       dtype='object')

# %% [markdown]
# ### Dropping duplicated rows...

# %%
cleaned_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
cleaned_data.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# ### Drop Nan...

# %%
cleaned_data.isna().sum()
# Out:
# Show_id         0
# Type            0
# Title           0
# Director        0
# Country         0
# Date_added      0
# Release_year    0
# Duration        0
# Listed_in       0
# dtype: int64

# %%
cleaned_data.dropna(axis=0, inplace=True)

# %% [markdown]
# ### Check for some more transformation...

# %%
cleaned_data['Show_id'].unique()
# Out:
# array(['s1', 's3', 's6', ..., 's8801', 's8784', 's8786'],
#       shape=(8790,), dtype=object)

# %%
# Extract the numeric part after 's' in Show_id
cleaned_data["Show_id_numeric"] = cleaned_data["Show_id"].str[1:]

cleaned_data["Show_id"] = cleaned_data["Show_id_numeric"].astype(int)

cleaned_data["Show_id"]
# Out:
# 0          1
# 1          3
# 2          6
# 3         14
# 4          8
#         ...
# 8785    8797
# 8786    8798
# 8787    8801
# 8788    8784
# 8789    8786
# Name: Show_id, Length: 8790, dtype: int64

# %%
cleaned_data["Date_added"]
# Out:
# 0        9/25/2021
# 1        9/24/2021
# 2        9/24/2021
# 3        9/22/2021
# 4        9/24/2021
#            ...
# 8785     1/17/2017
# 8786     9/13/2018
# 8787    12/15/2016
# 8788     6/23/2018
# 8789      6/7/2018
# Name: Date_added, Length: 8790, dtype: object

# %%
cleaned_data["Date_added"] = cleaned_data["Date_added"].apply(lambda x: x.replace("/", "-"))

cleaned_data["Date_added"] = cleaned_data["Date_added"].astype(str)

cleaned_data["Date_added"]
# Out:
# 0        9-25-2021
# 1        9-24-2021
# 2        9-24-2021
# 3        9-22-2021
# 4        9-24-2021
#            ...
# 8785     1-17-2017
# 8786     9-13-2018
# 8787    12-15-2016
# 8788     6-23-2018
# 8789      6-7-2018
# Name: Date_added, Length: 8790, dtype: object

# %%
cleaned_data.Country.value_counts()
# Out:
# Country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Luxembourg           1
# Senegal              1
# Belarus              1
# Puerto Rico          1
# Cyprus               1
# Name: count, Length: 86, dtype: int64

# %%
cleaned_data
# Out:
#       Show_id     Type                             Title         Director  \
# 0           1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1           3  TV Show                         Ganglands  Julien Leclercq
# 2           6  TV Show                     Midnight Mass    Mike Flanagan
# 3          14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4           8    Movie                           Sankofa     Haile Gerima
# ...       ...      ...                               ...              ...
# 8785     8797  TV Show                        Yunus Emre        Not Given
# 8786     8798  TV Show                         Zak Storm        Not Given
# 8787     8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788     8784  TV Show                              Yoko        Not Given
# 8789     8786  TV Show                               YOM        Not Given
#
#             Country  Date_added  Release_year   Duration  \
# ...

# %%
print(f"Total null values: {cleaned_data.isna().sum()}")

print(f"Total duplicate values: {cleaned_data.duplicated().sum()}")
# Out:
# Total null values: Show_id            0
# Type               0
# Title              0
# Director           0
# Country            0
# Date_added         0
# Release_year       0
# Duration           0
# Listed_in          0
# Show_id_numeric    0
# dtype: int64
# Total duplicate values: 0

# %% [markdown]
# ### Export the dataset

# %%
import os

os.makedirs("./data/cleaned_data", exist_ok=True)

cleaned_data.to_csv("./data/cleaned_data/netflix_cleaned_data.csv")

print("Expoted...")
# Out:
# Expoted...
